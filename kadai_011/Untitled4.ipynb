# %%
array = ["水","金","地","火","木","土","天","海","冥"]

#for文で9行printします
for array_v in array:
  print (array_v)

#while文で9行printします
idx = 0
while idx < 9:
  print (array[idx])
  idx = idx + 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
